# %%
##D31_Task 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
df_takehome_user_engagement = pd.read_csv('takehome_user_engagement.csv')
df_takehome_user_engagement.head()
# Out:
#             time_stamp  user_id  visited
# 0  2014-04-22 03:53:30        1        1
# 1  2013-11-15 03:45:04        2        1
# 2  2013-11-29 03:45:04        2        1
# 3  2013-12-09 03:45:04        2        1
# 4  2013-12-25 03:45:04        2        1

# %%
df =df_takehome_user_engagement.groupby(['user_id']).sum().reset_index()
df
# Out:
#       user_id  visited
# 0           1        1
# 1           2       14
# 2           3        1
# 3           4        1
# 4           5        1
# ...       ...      ...
# 8818    11996        1
# 8819    11997        1
# 8820    11998        1
# 8821    11999        1
# 8822    12000        1
#
# [8823 rows x 2 columns]

# %%
df.plot.bar(stacked=True)

# %%
df.plot.bar(rot=0)

# %%
df_takehome_users = pd.read_csv('takehome_users.csv', encoding = "ISO-8859-1")
df_takehome_users.head()
# Out:
#    object_id     creation_time               name                       email  \
# 0          1  22-04-2014 03:53     Clausen August    AugustCClausen@yahoo.com
# 1          2  15-11-2013 03:45      Poole Matthew      MatthewPoole@gustr.com
# 2          3  19-03-2013 23:14  Bottrill Mitchell  MitchellBottrill@gustr.com
# 3          4  21-05-2013 08:09    Clausen Nicklas   NicklasSClausen@yahoo.com
# 4          5  17-01-2013 10:14          Raw Grace          GraceRaw@yahoo.com
#
#   creation_source  last_session_creation_time  opted_in_to_mailing_list  \
# 0    GUEST_INVITE                1.398139e+09                         1
# 1      ORG_INVITE                1.396238e+09                         0
# 2      ORG_INVITE                1.363735e+09                         0
# 3    GUEST_INVITE                1.369210e+09                         0
# 4    GUEST_INVITE                1.358850e+09                         0
#
#    enabled_for_marketing_drip  org_id  invited_by_user_id
# ...

# %%
df_1 = df_takehome_users[["creation_source","object_id"]]
df_1
# Out:
#           creation_source  object_id
# 0            GUEST_INVITE          1
# 1              ORG_INVITE          2
# 2              ORG_INVITE          3
# 3            GUEST_INVITE          4
# 4            GUEST_INVITE          5
# ...                   ...        ...
# 11995          ORG_INVITE      11996
# 11996  SIGNUP_GOOGLE_AUTH      11997
# 11997        GUEST_INVITE      11998
# 11998   PERSONAL_PROJECTS      11999
# 11999              SIGNUP      12000
#
# [12000 rows x 2 columns]

# %%
x= df_1.groupby(['creation_source'])
x.first()
# Out:
#                     object_id
# creation_source
# GUEST_INVITE                1
# ORG_INVITE                  2
# PERSONAL_PROJECTS           8
# SIGNUP                      7
# SIGNUP_GOOGLE_AUTH         45

# %%
df_1.groupby(['object_id']).plot(kind='pie',y="creation_source", shadow=True, startangle=60)
